# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVC
from sklearn.datasets import make_moons

# %% [markdown]
# # Linear SVM Classification

# %%
X, y = make_moons(n_samples=200, noise=.1, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %% [markdown]
# # Polynomial Kernel

# %% [markdown]
# # Zad.
#
# Naucz SVM z jądrem "poly" o parametrach
#
# * degree=1, coef0=0, C=1
# * degree=2, coef0=0, C=1
# * degree=3, coef0=0, C=1
# * degree=3, coef0=1, C=1

# %%
# coef0 : float, optional (default=0.0)
# Independent term in kernel function. It is only significant in ‘poly’ and ‘sigmoid’.

degrees = [1, 2, 3, 3]
coef0s = [0, 0, 0, 1]
cs = [1, 1, 1, 1]

for degree, coef0, C in zip(degrees, coef0s, cs):
    poly_kernel_svm_clf = SVC(kernel="poly", degree=degree, coef0=coef0, C=C)
    poly_kernel_svm_clf.fit(X, y)
    plot_decision_regions(X, y, poly_kernel_svm_clf)
    plt.title(f"degree={degree}, coef0={coef0}, C={C}")
    plt.show()
